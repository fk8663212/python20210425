# %% [markdown]
# <a href="https://colab.research.google.com/github/fk8663212/python20210425/blob/main/yolov4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! nvidia-smi
# Out:
# Thu Feb 18 07:07:15 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
! sed -i "s/GPU=0/GPU=1/g" /content/darknet/Makefile
! sed -i "s/CUDNN=0/CUDNN=1/g" /content/darknet/Makefile
! sed -i "s/OPENCV=0/OPENCV=1/g" /content/darknet/Makefile
! head darknet/Makefile
# Out:
# GPU=1
# CUDNN=1
# CUDNN_HALF=0
# OPENCV=1
# AVX=0
# OPENMP=0
# LIBSO=0
# ZED_CAMERA=0
# ZED_CAMERA_v2_8=0

# %%
from PIL import Image

Image.open("./darknet/data/person.jpg")
! cd darknet; ./darknet detect /content/darknet/cfg/yolov4.cfg /content/drive/MyDrive/科展/深度學習/yolo_v4/yolov4.weights /content/drive/MyDrive/科展/深度學習/yolo_v4/測試/5a82dfc3e0882.jpg
from PIL import Image

Image.open("/content/darknet/predictions.jpg")
# Out:
#  CUDA-version: 10010 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 8, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    608 x 608 x   3 ->  608 x 608 x  32 0.639 BF
#    1 conv     64       3 x 3/ 2    608 x 608 x  32 ->  304 x 304 x  64 3.407 BF
#    2 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    3 route  1 		                           ->  304 x 304 x  64
#    4 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    5 conv     32       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  32 0.379 BF
#    6 conv     64       3 x 3/ 1    304 x 304 x  32 ->  304 x 304 x  64 3.407 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 304 x 304 x  64 0.006 BF
# ...

# %%
# !unzip "/content/drive/MyDrive/darknet.zip" -d "/content/"
# Out:
# Archive:  /content/drive/MyDrive/darknet.zip
#    creating: /content/darknet/
#   inflating: /content/darknet/net_cam_v3.sh
#    creating: /content/darknet/cfg/
#   inflating: /content/darknet/cfg/yolov3-tiny_occlusion_track.cfg
#   inflating: /content/darknet/cfg/yolo-voc.cfg
#   inflating: /content/darknet/cfg/yolov4.cfg
#   inflating: /content/darknet/cfg/tiny-yolo_xnor.cfg
#   inflating: /content/darknet/cfg/imagenet.labels.list
#   inflating: /content/darknet/cfg/strided.cfg
#   inflating: /content/darknet/cfg/imagenet22k.dataset
#   inflating: /content/darknet/cfg/tiny.cfg
#   inflating: /content/darknet/cfg/yolov3-tiny_xnor.cfg
#   inflating: /content/darknet/cfg/csdarknet53-omega.cfg
#   inflating: /content/darknet/cfg/yolov4-tiny_contrastive.cfg
#   inflating: /content/darknet/cfg/extraction.cfg
#   inflating: /content/darknet/cfg/enet-coco.cfg
#   inflating: /content/darknet/cfg/coco.data
#   inflating: /content/darknet/cfg/coco.names
# ...
